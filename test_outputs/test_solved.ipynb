# %% [markdown]
# # Solved Assignment
# Generated by AI Data Analyst

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load dataset (placeholder for local execution)
# df = pd.read_csv('your_dataset.csv')

# %% [markdown]
# ## Question: What is the total sales?

# %% [markdown]
# ### Analysis Approach
# I will sum the sales column.

# %%
df['sales'].sum()

# %% [markdown]
# ### Answer
# Total sales is 5000.

# %% [markdown]
# ## Question: Show top 5 products.

# %% [markdown]
# ### Analysis Approach
# I will sort by sales descending and take top 5.

# %%
df.sort_values('sales', ascending=False).head(5)

# %% [markdown]
# ### Answer
# Top 5 products are A, B, C, D, E.
